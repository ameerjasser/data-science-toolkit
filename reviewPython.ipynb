# %% [markdown]
# <a href="https://colab.research.google.com/github/ameerjasser/data-science-toolkit/blob/main/reviewPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x, y = True, False
print(x)
print(y)
print(type(x), x, y, x)
# Out:
# True
# False
# <class 'bool'> True False True

# %%
another_var = "{} {} {}".format(8,5, 45)
print(another_var)
print(type(another_var))
# Out:
# 8 5 45
# <class 'str'>

# %%
print(' Data '.strip())
# Out:
# Data

# %%
list = ['amir', 'pop', 15, True, "SOOO GOOD"]
print(list)
# Out:
# ['amir', 'pop', 15, True, 'SOOO GOOD']

# %%
list.append("Strories")
print(list)
# Out:
# ['amir', 'pop', 'Strories', 'Strories']

# %%
list.pop(2)
print(list)
# Out:
# ['amir', 'pop', True, 'SOOO GOOD']

# %%
import numpy as np

x = np.ones((2,2))
print(x)
# Out:
#   File "/tmp/ipython-input-3421529474.py", line 3
#     x = np.ones((2,2),,7)
#                       ^
# SyntaxError: invalid syntax

# %%
x = np.random.random((3,4))
print(x)
# Out:
# [[0.06312645 0.29980403 0.16221197 0.09830615]
#  [0.86264721 0.44992673 0.79298048 0.7486591 ]
#  [0.09144951 0.79136928 0.58392439 0.86237821]]

# %%
x = np.zeros((2,2))
print(x)

x = np.ones((2,2))
print(x)
# Out:
# [[0. 0.]
#  [0. 0.]]
# [[1. 1.]
#  [1. 1.]]

# %%
x = np.random.random((6,3)).T  # Transpose an array

print(x)
# Out:
# [[0.42651396 0.83101454 0.19848278 0.66218355 0.3614685  0.92628891]
#  [0.0037224  0.1060364  0.31863679 0.4315401  0.46660958 0.09397512]
#  [0.3876379  0.34507849 0.20162816 0.86810136 0.38645356 0.06187166]]

# %%
arr_1 = np.random.random((4,4))
arr_2 = np.random.random((4,4))

print(arr_1 * arr_2)
# Out:
# [[3.69595709e-01 5.02220694e-01 7.81910596e-01 8.81730796e-02]
#  [7.27621224e-01 2.27579874e-01 2.75988049e-01 2.68789725e-01]
#  [6.84894464e-01 9.70668497e-02 1.33297594e-01 4.73522942e-02]
#  [5.73744339e-04 8.58464778e-02 1.92477635e-01 3.29209626e-01]]

# %%
print(np.dot(arr_1, arr_2))
# Out:
# [[1.79983567 1.65886333 1.61498767 1.07445032]
#  [1.57817759 1.40486486 1.64674403 1.32481988]
#  [0.85454931 1.33932184 1.15646801 1.04503537]
#  [0.62120015 1.0158559  0.53773869 0.45467155]]
