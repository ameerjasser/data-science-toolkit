# %% [markdown]
# <a href="https://colab.research.google.com/github/ameerjasser/data-science-toolkit/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= "amir"
print("Welcome Data Sciencؤؤe",x)
# Out:
# Welcome Data Sciencؤؤe amir

# %%
fruits = ['apple','banana','other']

for ind, fruit in enumerate(fruits):
  print(f'{ind} : {fruit}')
# Out:
# 0 : apple
# 1 : banana
# 2 : other

# %%
x=['mangga','watermelon', 'musang-king','cempedak']
print('------')
print(len(x))

for i in range(len(x)):
  print(i)
# Out:
# ------
# 4
# 0
# 1
# 2
# 3

# %%
for i in range(len(x) - 1, -1, -1):
    print(i)
# Out:
# 3
# 2
# 1
# 0

# %%
x= [100,43,23,5,32,34]

# %%
for i in range(len(x) - 1, -1, -1):
    print(i)



    '''| Part             | Meaning                                                 |
| ---------------- | ------------------------------------------------------- |
| `len(x)-1` → `3` | Start at index **3**                                    |
| `-1`             | Stop **before** reaching -1 → means last value is **0** |
| `-1`             | Move **backwards** by 1 each time                       |
'''
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# #Functions (in java is called methods)

# %%
x=1
y=2
def addition(x,y):
  z = x + y
  return z


z = addition(x,y)
print(z)
# Out:
# 3

# %% [markdown]
# #Multiplication table for 7 up to 17

# %%
for i in range(1,18,1):                         #  (1 the start, 18 the end, 1 the number of step and you can go back -1 , -2 and so on)
  print(f'{i}x7 = {i*7}')
# Out:
# 4x7 = 28
# 6x7 = 42
# 8x7 = 56
# 10x7 = 70
# 12x7 = 84
# 14x7 = 98
# 16x7 = 112
# 18x7 = 126
